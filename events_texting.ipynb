# %%
import pandas as pd

def load_large_excel(file_path):
    """
    Загружает большой Excel-файл с оптимизацией памяти.
    
    Параметры:
        file_path (str): Путь к файлу Excel (.xlsx или .xls).
    
    Возвращает:
        pd.DataFrame или None: Загруженные данные или None в случае ошибки.
    """
    try:
        # Определяем типы столбцов заранее, чтобы уменьшить использование памяти
        dtype_spec = {
            'Reposts': 'int32',    # Экономит память по сравнению с int64
            'Views': 'int32',
            'Link': 'string',       # Оптимизированная строка (вместо object)
            'Text': 'string'
        }
        
        # Чтение файла с оптимизацией
        df = pd.read_excel(
            file_path,
            engine='openpyxl',      # Лучше для .xlsx (для .xls можно 'xlrd')
            dtype=dtype_spec,       # Задаём типы сразу при чтении
            usecols=['Reposts', 'Views', 'Link', 'Text'],  # Читаем только нужные столбцы
            # na_values=['NA', 'N/A', ''],  # Обработка пропущенных значений
            keep_default_na=False   # Уменьшает нагрузку на память
        )
        
        # Заполняем возможные пропуски (если не критичны)
        df['Reposts'] = df['Reposts'].fillna(0).astype('int32')
        df['Views'] = df['Views'].fillna(0).astype('int32')
        
        return df
    
    except FileNotFoundError:
        print(f"Ошибка: Файл не найден — {file_path}")
    except Exception as e:
        print(f"Ошибка при загрузке Excel: {e}")
    
    return None

# %%
file_path = "dset_vk_2024.xlsx"  # Укажите свой путь
data = load_large_excel(file_path)

if data is not None:
    print("Данные успешно загружены:")
    print(f"Всего строк: {len(data)}")
    print(data.head())
# Out:
# Данные успешно загружены:
# Всего строк: 156672
#    Reposts  Views                               Link  \
# 0        0    244  https://vk.com/wall-6121824_29834
# 1        0    197  https://vk.com/wall-6121824_29833
# 2        1    317  https://vk.com/wall-6121824_29832
# 3        0    260  https://vk.com/wall-6121824_29831
# 4        0    354  https://vk.com/wall-6121824_29830
#
#                                                 Text
# 0  Поздравление врио Главы Республики Коми Ростис...
# 1  На Украине признали самый низкий уровень рожда...
# 2  Жителей России призвали воздержаться от исполь...
# 3  🇷🇺 Жители Коми выбирают название новой кадрово...
# 4  🏆 Для титулованных спортсменов из Республики К...

# %%
import spacy
import re

# Загружаем модель для русского языка
nlp = spacy.load("ru_core_news_sm")

# def merge_dicts(lhs, rhs):
#     for k in ["action", "subjects"]:
#         lhs[k] += rhs[k]
#     return lhs

def token_chunk(token):
    return [t.text for t in token.subtree]

def find_mods(token):
    modifiers = set()
    for token_ in token.children:
        if token_.dep_ in ["nmod", "amod", "advmod"]:
            modifiers.add(token_.text)
            modifiers.update(find_mods(token_))
    return modifiers

def explote_subtree(token):
    modifiers = []
    elements = []
    for token_ in token.children:
        if token_.dep_ in ["nmod", "amod", "advmod"]: 
            modifiers.append([token_.text, find_mods(token_)])
        if token_.dep_ == "conj":
            elements += explote_subtree(token_)
    elements.append({"item" : token.text, "modifiers" : modifiers})
    return elements

def find_iobj(token):
    iobjs = []
    for token_ in token.subtree:
        if token != token_:
            if token_.dep_ in ["iobj", "obj", "nsubj:pass"]:
                iobjs.append(explote_subtree(token_))
    if iobjs == []:
        return None
    else:
        return iobjs
    
def find_subj(token):
    subjs = []
    for token_ in token.subtree:
        if token != token_:
            if token_.dep_ in ["nsubj"]:
                subjs.append(explote_subtree(token_))
    if subjs == []:
        return None
    else:
        return subjs
    
def search_from_root(token):
    this_predicate = {"action" : [token.text], "subjects" : [], "objects" : []}
    # непрямые объекты (если через что-то обращены), обрабатываются отдельно
    iobjs = find_iobj(token)
    if iobjs is not None:
        this_predicate["objects"] += iobjs
    subjs = find_subj(token)
    if subjs is not None:
        this_predicate["subjects"] += subjs

    for token_ in token.children:
        if token_.dep_ in ["xcomp", "csubj:pass", "conj"]: # то надо воспринимать его, как еще один рут
            this_predicate["action"].append(token_.text)
    return this_predicate

def analyze_sentence(sentence):
    print(sentence)
    """Анализирует предложение и возвращает подлежащее и сказуемое."""
    doc = nlp(sentence)
    
    predicates = []  # сказуемое (глагол или связка)
    ne = []
    
    for token in doc:
        if token.dep_ in ["ROOT"]:
            predicates.append(search_from_root(token))

        print(token, token.pos_, token.morph.get("Case", []), "\t", token.dep_, "  |  ", token.head)

        if token.pos_ == "PROPN":
            nes = explote_subtree(token)
            ne_reprs = []
            for item in nes:
                mod_reprs = []
                for mod in item["modifiers"]:
                    main_mod = mod[0]
                    mod_props = ' '.join(elm for elm in mod[1])
                    mod_repr = main_mod + " " + mod_props
                    mod_reprs.append(mod_repr)
                ne_reprs.append(item["item"] + " " + " ".join(mod_reprs))
            ne.append(' '.join(ne_reprs).strip())          

    
    return {"predicates": predicates, "named entities" : ne}

def get_text_main_part(text):
    for sep in ['. ', '\n']:
        text =  text.replace(sep, '¬')
    sentences = [sent for sent in text.split('¬')]  # Разбиваем текст на предложения

    anres = []
    for sent in sentences:
        sent = re.sub(r'[^а-яё.,:()\[\]0-9А-Я]', ' ', sent)
        sent = re.sub('\s+', ' ', sent)
        analysis = analyze_sentence(sent)
        anres.append(analysis)
        print(analysis)
    return anres
# Out:
# <>:109: SyntaxWarning: invalid escape sequence '\s'
# <>:109: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\User\AppData\Local\Temp\ipykernel_1564\1157283608.py:109: SyntaxWarning: invalid escape sequence '\s'
#   sent = re.sub('\s+', ' ', sent)

# %%
ans = []
for text in data['Text'][0:20]:
    ans.append(get_text_main_part(text))
# Out:
# Поздравление врио Главы Республики Коми Ростислава Гольдштейна с наступающим Новым годом
# Поздравление NOUN ['Nom'] 	 ROOT   |   Поздравление
# врио NOUN ['Gen'] 	 nmod   |   Поздравление
# Главы NOUN ['Gen'] 	 nmod   |   врио
# Республики PROPN ['Gen'] 	 nmod   |   Главы
# Коми PROPN ['Gen'] 	 appos   |   врио
# Ростислава PROPN ['Gen'] 	 flat:name   |   Коми
# Гольдштейна PROPN ['Gen'] 	 flat:name   |   Коми
# с ADP [] 	 case   |   годом
# наступающим VERB ['Ins'] 	 amod   |   годом
# Новым ADJ ['Ins'] 	 amod   |   годом
# годом NOUN ['Ins'] 	 nmod   |   Поздравление
# {'predicates': [{'action': ['Поздравление'], 'subjects': [], 'objects': []}], 'named entities': ['Республики', 'Коми', 'Ростислава', 'Гольдштейна']}
# На Украине признали самый низкий уровень рождаемости на планете 000
# На ADP [] 	 case   |   Украине
# Украине PROPN ['Loc'] 	 obl   |   признали
# признали VERB [] 	 ROOT   |   признали
# самый ADJ ['Acc'] 	 amod   |   низкий
# низкий ADJ ['Acc'] 	 amod   |   уровень
# уровень NOUN ['Acc'] 	 obj   |   признали
# рождаемости NOUN ['Gen'] 	 nmod   |   уровень
# на ADP [] 	 case   |   планете
# планете NOUN ['Loc'] 	 nmod   |   рождаемости
# 000 NUM [] 	 appos   |   уровень
# {'predicates': [{'action': ['признали'], 'subjects': [], 'objects': [[{'item': 'уровень', 'modifiers': [['низкий', {'самый'}], ['рождаемости', {'планете'}]]}]]}], 'named entities': ['Украине']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# На Украине самый высокий уровень смертности и самый низкий уровень рождаемости в мире
# На ADP [] 	 case   |   Украине
# Украине PROPN ['Loc'] 	 ROOT   |   Украине
# самый ADJ ['Nom'] 	 amod   |   высокий
# высокий ADJ ['Nom'] 	 amod   |   уровень
# уровень NOUN ['Acc'] 	 nsubj   |   Украине
# смертности NOUN ['Gen'] 	 nmod   |   уровень
# и CCONJ [] 	 cc   |   уровень
# самый ADJ ['Nom'] 	 amod   |   низкий
# низкий ADJ ['Nom'] 	 amod   |   уровень
# уровень NOUN ['Nom'] 	 conj   |   уровень
# рождаемости NOUN ['Gen'] 	 nmod   |   уровень
# в ADP [] 	 case   |   мире
# мире NOUN ['Loc'] 	 nmod   |   рождаемости
# {'predicates': [{'action': ['Украине'], 'subjects': [[{'item': 'уровень', 'modifiers': [['низкий', {'самый'}], ['рождаемости', {'мире'}]]}, {'item': 'уровень', 'modifiers': [['высокий', {'самый'}], ['смертности', set()]]}]], 'objects': []}], 'named entities': ['Украине']}
# Об этом сообщила депутат, член комитета Верховной Рады по вопросам здоровья нации Виктория Вагнер, передает Страна. . 000
# Об ADP [] 	 case   |   этом
# этом PRON ['Loc'] 	 obl   |   сообщила
# сообщила VERB [] 	 ROOT   |   сообщила
# депутат NOUN ['Nom'] 	 nsubj   |   сообщила
# , PUNCT [] 	 punct   |   член
# член NOUN ['Nom'] 	 appos   |   депутат
# комитета NOUN ['Gen'] 	 nmod   |   член
# Верховной ADJ ['Gen'] 	 amod   |   Рады
# Рады PROPN ['Gen'] 	 nmod   |   комитета
# по ADP [] 	 case   |   вопросам
# вопросам NOUN ['Dat'] 	 nmod   |   комитета
# здоровья NOUN ['Gen'] 	 nmod   |   вопросам
# нации NOUN ['Gen'] 	 nmod   |   здоровья
# Виктория PROPN ['Nom'] 	 appos   |   член
# Вагнер PROPN ['Nom'] 	 flat:name   |   Виктория
# , PUNCT [] 	 punct   |   передает
# передает VERB [] 	 parataxis   |   сообщила
# Страна PROPN ['Nom'] 	 nsubj   |   передает
# . PUNCT [] 	 punct   |   сообщила
# . PUNCT [] 	 punct   |   сообщила
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['сообщила'], 'subjects': [[{'item': 'депутат', 'modifiers': []}], [{'item': 'Страна', 'modifiers': []}]], 'objects': []}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['Рады Верховной', 'Виктория', 'Вагнер', 'Страна']}
# По данным Министерства юстиции Украины, на которые сослалась парламентарий, в 2024 году с января по июнь включительно в стране родились 87 655 и умерло 250 972 человек
# По ADP [] 	 case   |   данным
# данным NOUN ['Dat'] 	 parataxis   |   родились
# Министерства PROPN ['Gen'] 	 nmod   |   данным
# юстиции NOUN ['Gen'] 	 nmod   |   Министерства
# Украины PROPN ['Gen'] 	 nmod   |   Министерства
# , PUNCT [] 	 punct   |   сослалась
# на ADP [] 	 case   |   которые
# которые PRON ['Acc'] 	 obl   |   сослалась
# сослалась VERB [] 	 acl:relcl   |   данным
# парламентарий NOUN ['Nom'] 	 nsubj   |   сослалась
# , PUNCT [] 	 punct   |   данным
# в ADP [] 	 case   |   году
# 2024 ADJ [] 	 amod   |   году
# году NOUN ['Loc'] 	 obl   |   родились
# с ADP [] 	 case   |   января
# января NOUN ['Gen'] 	 obl   |   родились
# по ADP [] 	 case   |   июнь
# июнь NOUN ['Acc'] 	 nmod   |   января
# включительно ADV [] 	 advmod   |   родились
# в ADP [] 	 case   |   стране
# стране NOUN ['Loc'] 	 obl   |   родились
# родились VERB [] 	 ROOT   |   родились
# 87 NUM [] 	 nummod   |   655
# 655 NUM [] 	 nsubj   |   родились
# и CCONJ [] 	 cc   |   умерло
# умерло VERB [] 	 conj   |   родились
# 250 NUM [] 	 nummod   |   972
# 972 NUM [] 	 nsubj   |   умерло
# человек NOUN ['Gen'] 	 nsubj   |   родились
# {'predicates': [{'action': ['родились', 'умерло'], 'subjects': [[{'item': 'парламентарий', 'modifiers': []}], [{'item': '655', 'modifiers': []}], [{'item': '972', 'modifiers': []}], [{'item': 'человек', 'modifiers': []}]], 'objects': []}], 'named entities': ['Министерства юстиции  Украины', 'Украины']}
# Депутат заключила, что в 2024 году смертность в стране почти втрое превышает рождаемость, при том что в период с 2018 по 2020 год этот показатель был на уровне 2:1. 000
# Депутат NOUN ['Nom'] 	 nsubj   |   заключила
# заключила VERB [] 	 ROOT   |   заключила
# , PUNCT [] 	 punct   |   превышает
# что SCONJ [] 	 mark   |   превышает
# в ADP [] 	 case   |   году
# 2024 ADJ [] 	 amod   |   году
# году NOUN ['Loc'] 	 obl   |   превышает
# смертность NOUN ['Nom'] 	 nsubj   |   превышает
# в ADP [] 	 case   |   стране
# стране NOUN ['Loc'] 	 nmod   |   смертность
# почти ADV [] 	 advmod   |   втрое
# втрое ADV [] 	 advmod   |   превышает
# превышает VERB [] 	 ccomp   |   заключила
# рождаемость NOUN ['Acc'] 	 obj   |   превышает
# , PUNCT [] 	 punct   |   том
# при ADP [] 	 case   |   том
# том PRON ['Loc'] 	 nmod   |   рождаемость
# что SCONJ [] 	 mark   |   уровне
# в ADP [] 	 case   |   период
# период NOUN ['Acc'] 	 nmod   |   уровне
# с ADP [] 	 case   |   2018
# 2018 ADJ [] 	 nmod   |   период
# по ADP [] 	 case   |   год
# 2020 ADJ [] 	 amod   |   год
# год NOUN ['Acc'] 	 obl   |   2018
# этот DET ['Nom'] 	 det   |   показатель
# показатель NOUN ['Nom'] 	 nsubj   |   уровне
# был AUX [] 	 cop   |   уровне
# на ADP [] 	 case   |   уровне
# уровне NOUN ['Loc'] 	 acl   |   том
# 2:1 NUM [] 	 nmod   |   уровне
# . PUNCT [] 	 punct   |   заключила
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['заключила'], 'subjects': [[{'item': 'Депутат', 'modifiers': []}], [{'item': 'смертность', 'modifiers': [['стране', set()]]}], [{'item': 'показатель', 'modifiers': []}]], 'objects': [[{'item': 'рождаемость', 'modifiers': [['том', set()]]}]]}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# Источник: : . 2024 12 09
# Источник NOUN ['Nom'] 	 ROOT   |   Источник
# : PUNCT [] 	 punct   |   Источник
# : PUNCT [] 	 punct   |   .
# . PUNCT [] 	 punct   |   Источник
# 2024 NUM [] 	 ROOT   |   2024
# 12 NUM [] 	 flat   |   2024
# 09 NUM [] 	 flat   |   2024
# {'predicates': [{'action': ['Источник'], 'subjects': [], 'objects': []}, {'action': ['2024'], 'subjects': [], 'objects': []}], 'named entities': []}
# Жителей России призвали воздержаться от использования пиротехники. 000
# Жителей NOUN ['Acc'] 	 obj   |   призвали
# России PROPN ['Gen'] 	 nmod   |   Жителей
# призвали VERB [] 	 ROOT   |   призвали
# воздержаться VERB [] 	 xcomp   |   призвали
# от ADP [] 	 case   |   использования
# использования NOUN ['Gen'] 	 obl   |   воздержаться
# пиротехники NOUN ['Gen'] 	 nmod   |   использования
# . PUNCT [] 	 punct   |   призвали
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['призвали', 'воздержаться'], 'subjects': [], 'objects': [[{'item': 'Жителей', 'modifiers': [['России', set()]]}]]}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['России']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# Данные меры связаны с информацией о поставке украинскими спецслужбами в Россию фальсифицированной пиротехники (салюты, фейерверки, петарды и прочее) опасной для жизни и здоровья граждан. 000
# Данные DET ['Nom'] 	 amod   |   меры
# меры NOUN ['Nom'] 	 nsubj:pass   |   связаны
# связаны VERB [] 	 ROOT   |   связаны
# с ADP [] 	 case   |   информацией
# информацией NOUN ['Ins'] 	 obl   |   связаны
# о ADP [] 	 case   |   поставке
# поставке NOUN ['Loc'] 	 nmod   |   информацией
# украинскими ADJ ['Ins'] 	 amod   |   спецслужбами
# спецслужбами NOUN ['Ins'] 	 nmod   |   поставке
# в ADP [] 	 case   |   Россию
# Россию PROPN ['Acc'] 	 nmod   |   поставке
# фальсифицированной VERB ['Gen'] 	 amod   |   пиротехники
# пиротехники NOUN ['Gen'] 	 nmod   |   поставке
# ( PUNCT [] 	 punct   |   салюты
# салюты NOUN ['Gen'] 	 parataxis   |   пиротехники
# , PUNCT [] 	 punct   |   фейерверки
# фейерверки NOUN ['Nom'] 	 conj   |   салюты
# , PUNCT [] 	 punct   |   петарды
# петарды NOUN ['Nom'] 	 conj   |   салюты
# и CCONJ [] 	 cc   |   прочее
# прочее ADJ ['Acc'] 	 conj   |   салюты
# ) PUNCT [] 	 punct   |   салюты
# опасной ADJ ['Gen'] 	 nmod   |   поставке
# для ADP [] 	 case   |   жизни
# жизни NOUN ['Gen'] 	 obl   |   опасной
# и CCONJ [] 	 cc   |   здоровья
# здоровья NOUN ['Gen'] 	 conj   |   жизни
# граждан NOUN ['Gen'] 	 nmod   |   здоровья
# . PUNCT [] 	 punct   |   связаны
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['связаны'], 'subjects': [], 'objects': [[{'item': 'меры', 'modifiers': [['Данные', set()]]}]]}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['Россию']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# Подобные пиротехнические изделия могут выглядеть как настоящие
# Подобные ADJ ['Nom'] 	 amod   |   изделия
# пиротехнические ADJ ['Nom'] 	 amod   |   изделия
# изделия NOUN ['Nom'] 	 nsubj   |   могут
# могут VERB [] 	 ROOT   |   могут
# выглядеть VERB [] 	 xcomp   |   могут
# как SCONJ [] 	 mark   |   настоящие
# настоящие ADJ ['Nom'] 	 advcl   |   могут
# {'predicates': [{'action': ['могут', 'выглядеть'], 'subjects': [[{'item': 'изделия', 'modifiers': [['Подобные', set()], ['пиротехнические', set()]]}]], 'objects': []}], 'named entities': []}
# Но в них заложены взрывчатые вещества большей мощности, срабатывающие мгновенно, что увеличивает риск получения травм.
# Но CCONJ [] 	 cc   |   заложены
# в ADP [] 	 case   |   них
# них PRON ['Loc'] 	 obl   |   заложены
# заложены VERB [] 	 ROOT   |   заложены
# взрывчатые ADJ ['Nom'] 	 amod   |   вещества
# вещества NOUN ['Nom'] 	 nsubj:pass   |   заложены
# большей ADJ ['Gen'] 	 amod   |   мощности
# мощности NOUN ['Gen'] 	 nmod   |   вещества
# , PUNCT [] 	 punct   |   срабатывающие
# срабатывающие VERB ['Nom'] 	 acl   |   вещества
# мгновенно ADV [] 	 advmod   |   срабатывающие
# , PUNCT [] 	 punct   |   увеличивает
# что PRON ['Nom'] 	 nsubj   |   увеличивает
# увеличивает VERB [] 	 ccomp   |   срабатывающие
# риск NOUN ['Acc'] 	 obj   |   увеличивает
# получения NOUN ['Gen'] 	 nmod   |   риск
# травм NOUN ['Gen'] 	 nmod   |   получения
# . PUNCT [] 	 punct   |   заложены
# {'predicates': [{'action': ['заложены'], 'subjects': [[{'item': 'что', 'modifiers': []}]], 'objects': [[{'item': 'вещества', 'modifiers': [['взрывчатые', set()], ['мощности', {'большей'}]]}], [{'item': 'риск', 'modifiers': [['получения', {'травм'}]]}]]}], 'named entities': []}
#  Жители Коми выбирают название новой кадровой управленческой программе 000
#   SPACE [] 	 dep   |   Жители
# Жители NOUN ['Nom'] 	 nsubj   |   выбирают
# Коми PROPN ['Gen'] 	 nmod   |   Жители
# выбирают VERB [] 	 ROOT   |   выбирают
# название NOUN ['Acc'] 	 obj   |   выбирают
# новой ADJ ['Gen'] 	 amod   |   программе
# кадровой ADJ ['Gen'] 	 amod   |   программе
# управленческой ADJ ['Gen'] 	 amod   |   программе
# программе NOUN ['Dat'] 	 nmod   |   название
# 000 NUM [] 	 appos   |   программе
# {'predicates': [{'action': ['выбирают'], 'subjects': [[{'item': 'Жители', 'modifiers': [['Коми', set()]]}]], 'objects': [[{'item': 'название', 'modifiers': [['программе', {'управленческой', 'кадровой', 'новой'}]]}]]}], 'named entities': ['Коми']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# По аналогии с федеральным проектом Время героев она будет ориентирована на ветеранов СВО, но только из нашей республики
# По ADP [] 	 case   |   аналогии
# аналогии NOUN ['Dat'] 	 obl   |   ориентирована
# с ADP [] 	 case   |   проектом
# федеральным ADJ ['Ins'] 	 amod   |   проектом
# проектом NOUN ['Ins'] 	 nmod   |   аналогии
# Время NOUN ['Nom'] 	 nmod   |   аналогии
# героев NOUN ['Gen'] 	 nmod   |   Время
# она PRON ['Nom'] 	 nsubj:pass   |   ориентирована
# будет AUX [] 	 aux:pass   |   ориентирована
# ориентирована VERB [] 	 ROOT   |   ориентирована
# на ADP [] 	 case   |   ветеранов
# ветеранов NOUN ['Acc'] 	 obl   |   ориентирована
# СВО PROPN ['Gen'] 	 nmod   |   ветеранов
# , PUNCT [] 	 punct   |   республики
# но CCONJ [] 	 cc   |   республики
# только PART [] 	 advmod   |   республики
# из ADP [] 	 case   |   республики
# нашей DET ['Gen'] 	 det   |   республики
# республики NOUN ['Gen'] 	 punct   |   ориентирована
# {'predicates': [{'action': ['ориентирована'], 'subjects': [], 'objects': [[{'item': 'она', 'modifiers': []}]]}], 'named entities': ['СВО']}
# Её запуск планируется уже с января 2025 года
# Её ADJ ['Nom'] 	 amod   |   запуск
# запуск NOUN ['Nom'] 	 nsubj:pass   |   планируется
# планируется VERB [] 	 ROOT   |   планируется
# уже ADV [] 	 advmod   |   января
# с ADP [] 	 case   |   января
# января NOUN ['Gen'] 	 obl   |   планируется
# 2025 ADJ [] 	 amod   |   года
# года NOUN ['Gen'] 	 nmod   |   января
# {'predicates': [{'action': ['планируется'], 'subjects': [], 'objects': [[{'item': 'запуск', 'modifiers': [['Её', set()]]}]]}], 'named entities': []}
# В результате обучения будет сформирован кадровый резерв для работы в органах власти Коми
# В ADP [] 	 case   |   результате
# результате NOUN ['Loc'] 	 obl   |   сформирован
# обучения NOUN ['Gen'] 	 nmod   |   результате
# будет AUX [] 	 aux:pass   |   сформирован
# сформирован VERB [] 	 ROOT   |   сформирован
# кадровый ADJ ['Nom'] 	 amod   |   резерв
# резерв NOUN ['Nom'] 	 nsubj:pass   |   сформирован
# для ADP [] 	 case   |   работы
# работы NOUN ['Gen'] 	 nmod   |   резерв
# в ADP [] 	 case   |   органах
# органах NOUN ['Loc'] 	 nmod   |   работы
# власти NOUN ['Gen'] 	 nmod   |   органах
# Коми PROPN ['Gen'] 	 nmod   |   резерв
# {'predicates': [{'action': ['сформирован'], 'subjects': [], 'objects': [[{'item': 'резерв', 'modifiers': [['кадровый', set()], ['работы', {'органах', 'власти'}], ['Коми', set()]]}]]}], 'named entities': ['Коми']}
# Такую идею предложил врио Главы Коми Ростислав Гольдштейн. 000
# Такую DET ['Acc'] 	 det   |   идею
# идею NOUN ['Acc'] 	 obj   |   предложил
# предложил VERB [] 	 ROOT   |   предложил
# врио NOUN ['Nom'] 	 nsubj   |   предложил
# Главы PROPN ['Gen'] 	 nmod   |   врио
# Коми PROPN ['Gen'] 	 nmod   |   Главы
# Ростислав PROPN ['Nom'] 	 appos   |   врио
# Гольдштейн PROPN ['Nom'] 	 flat:name   |   Ростислав
# . PUNCT [] 	 punct   |   предложил
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['предложил'], 'subjects': [[{'item': 'врио', 'modifiers': [['Главы', {'Коми'}]]}]], 'objects': [[{'item': 'идею', 'modifiers': []}]]}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['Главы Коми', 'Коми', 'Ростислав', 'Гольдштейн']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
#  Варианты названий программы собирает (Общественная палата)
#   SPACE [] 	 dep   |   Варианты
# Варианты NOUN ['Nom'] 	 nsubj   |   собирает
# названий NOUN ['Gen'] 	 nmod   |   Варианты
# программы NOUN ['Gen'] 	 nmod   |   названий
# собирает VERB [] 	 ROOT   |   собирает
# ( PUNCT [] 	 punct   |   палата
# Общественная ADJ ['Nom'] 	 amod   |   палата
# палата NOUN ['Nom'] 	 parataxis   |   собирает
# ) PUNCT [] 	 punct   |   палата
# {'predicates': [{'action': ['собирает'], 'subjects': [[{'item': 'Варианты', 'modifiers': [['названий', {'программы'}]]}]], 'objects': []}], 'named entities': []}
# Поторопитесь внести свой вклад, сегодня последний день, когда можно предложить название
# Поторопитесь VERB [] 	 ROOT   |   Поторопитесь
# внести VERB [] 	 xcomp   |   Поторопитесь
# свой DET ['Acc'] 	 det   |   вклад
# вклад NOUN ['Acc'] 	 obj   |   внести
# , PUNCT [] 	 punct   |   день
# сегодня ADV [] 	 advmod   |   день
# последний ADJ ['Nom'] 	 amod   |   день
# день NOUN ['Acc'] 	 conj   |   Поторопитесь
# , PUNCT [] 	 punct   |   можно
# когда ADV [] 	 advmod   |   можно
# можно ADV [] 	 acl:relcl   |   день
# предложить VERB [] 	 csubj   |   можно
# название NOUN ['Acc'] 	 obj   |   предложить
# {'predicates': [{'action': ['Поторопитесь', 'внести', 'день'], 'subjects': [], 'objects': [[{'item': 'вклад', 'modifiers': []}], [{'item': 'название', 'modifiers': []}]]}], 'named entities': []}
# Затем начнётся голосование. 000
# Затем ADV [] 	 advmod   |   начнётся
# начнётся VERB [] 	 ROOT   |   начнётся
# голосование NOUN ['Nom'] 	 nsubj   |   начнётся
# . PUNCT [] 	 punct   |   начнётся
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['начнётся'], 'subjects': [[{'item': 'голосование', 'modifiers': []}]], 'objects': []}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
#  : . 48293308 456246524
#   SPACE [] 	 dep   |
# : PUNCT [] 	 ROOT   |   :
# . PUNCT [] 	 punct   |   :
# 48293308 ADJ [] 	 ROOT   |   48293308
# 456246524 ADJ [] 	 flat   |   48293308
# {'predicates': [{'action': [':'], 'subjects': [], 'objects': []}, {'action': ['48293308'], 'subjects': [], 'objects': []}], 'named entities': []}
#  Для титулованных спортсменов из Республики Коми вводятся новые выплаты 000
#   SPACE [] 	 dep   |   Для
# Для ADP [] 	 case   |   спортсменов
# титулованных ADJ ['Gen'] 	 amod   |   спортсменов
# спортсменов NOUN ['Gen'] 	 obl   |   вводятся
# из ADP [] 	 case   |   Республики
# Республики PROPN ['Gen'] 	 nmod   |   спортсменов
# Коми PROPN ['Nom'] 	 appos   |   Республики
# вводятся VERB [] 	 ROOT   |   вводятся
# новые ADJ ['Nom'] 	 amod   |   выплаты
# выплаты NOUN ['Nom'] 	 nsubj:pass   |   вводятся
# 000 NUM [] 	 punct   |   вводятся
# {'predicates': [{'action': ['вводятся'], 'subjects': [], 'objects': [[{'item': 'выплаты', 'modifiers': [['новые', set()]]}]]}], 'named entities': ['Республики', 'Коми']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# По словам Ростислава Гольдштейна, с 1 января победителям чемпионатов и первенств России будут выплачивать стипендию в размере 10 000 рублей ежемесячно в течение спортивного сезона
# По ADP [] 	 case   |   словам
# словам NOUN ['Dat'] 	 parataxis   |   выплачивать
# Ростислава PROPN ['Gen'] 	 nmod   |   словам
# Гольдштейна PROPN ['Gen'] 	 flat:name   |   Ростислава
# , PUNCT [] 	 punct   |   словам
# с ADP [] 	 case   |   1
# 1 ADJ [] 	 obl   |   выплачивать
# января NOUN ['Gen'] 	 flat   |   1
# победителям NOUN ['Dat'] 	 iobj   |   выплачивать
# чемпионатов NOUN ['Gen'] 	 nmod   |   победителям
# и CCONJ [] 	 cc   |   первенств
# первенств NOUN ['Gen'] 	 conj   |   чемпионатов
# России PROPN ['Gen'] 	 nmod   |   первенств
# будут AUX [] 	 aux   |   выплачивать
# выплачивать VERB [] 	 ROOT   |   выплачивать
# стипендию NOUN ['Acc'] 	 obj   |   выплачивать
# в ADP [] 	 case   |   размере
# размере NOUN ['Loc'] 	 nmod   |   стипендию
# 10 NUM [] 	 nummod   |   000
# 000 NUM [] 	 nummod   |   рублей
# рублей NOUN ['Gen'] 	 nmod   |   размере
# ежемесячно ADV [] 	 advmod   |   выплачивать
# в ADP [] 	 case   |   сезона
# течение NOUN ['Acc'] 	 fixed   |   в
# спортивного ADJ ['Gen'] 	 amod   |   сезона
# сезона NOUN ['Gen'] 	 obl   |   выплачивать
# {'predicates': [{'action': ['выплачивать'], 'subjects': [], 'objects': [[{'item': 'победителям', 'modifiers': [['чемпионатов', set()]]}], [{'item': 'стипендию', 'modifiers': [['размере', {'рублей'}]]}]]}], 'named entities': ['Ростислава', 'Гольдштейна', 'России']}
# Так поддержат членов сборных команд Коми по летним и зимним видам спорта, включённым в программы Олимпийских, Паралимпийских и Сурдлимпийских игр, которые показали высокий результат. 000
# Так ADV [] 	 advmod   |   поддержат
# поддержат VERB [] 	 ROOT   |   поддержат
# членов NOUN ['Acc'] 	 obj   |   поддержат
# сборных ADJ ['Gen'] 	 amod   |   команд
# команд NOUN ['Gen'] 	 nmod   |   членов
# Коми PROPN ['Gen'] 	 nmod   |   команд
# по ADP [] 	 case   |   видам
# летним ADJ ['Dat'] 	 amod   |   видам
# и CCONJ [] 	 cc   |   зимним
# зимним ADJ ['Dat'] 	 conj   |   летним
# видам NOUN ['Dat'] 	 nmod   |   членов
# спорта NOUN ['Gen'] 	 nmod   |   видам
# , PUNCT [] 	 punct   |   включённым
# включённым VERB ['Dat'] 	 acl   |   видам
# в ADP [] 	 case   |   программы
# программы NOUN ['Acc'] 	 obl   |   включённым
# Олимпийских ADJ ['Gen'] 	 amod   |   игр
# , PUNCT [] 	 punct   |   Паралимпийских
# Паралимпийских ADJ ['Gen'] 	 conj   |   Олимпийских
# и CCONJ [] 	 cc   |   Сурдлимпийских
# Сурдлимпийских ADJ ['Gen'] 	 conj   |   Олимпийских
# игр NOUN ['Gen'] 	 nmod   |   программы
# , PUNCT [] 	 punct   |   показали
# которые PRON ['Nom'] 	 nsubj   |   показали
# показали VERB [] 	 acl:relcl   |   игр
# высокий ADJ ['Acc'] 	 amod   |   результат
# результат NOUN ['Acc'] 	 obj   |   показали
# . PUNCT [] 	 punct   |   поддержат
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['поддержат'], 'subjects': [[{'item': 'которые', 'modifiers': []}]], 'objects': [[{'item': 'членов', 'modifiers': [['команд', {'сборных', 'Коми'}], ['видам', {'спорта', 'летним'}]]}], [{'item': 'результат', 'modifiers': [['высокий', set()]]}]]}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['Коми']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# Сейчас российские спортсмены отстранены от участия в больших международных соревнованиях, поэтому наша республика будет поддерживать своих ребят
# Сейчас ADV [] 	 advmod   |   отстранены
# российские ADJ ['Nom'] 	 amod   |   спортсмены
# спортсмены NOUN ['Nom'] 	 nsubj:pass   |   отстранены
# отстранены VERB [] 	 ROOT   |   отстранены
# от ADP [] 	 case   |   участия
# участия NOUN ['Gen'] 	 obl   |   отстранены
# в ADP [] 	 case   |   соревнованиях
# больших ADJ ['Loc'] 	 amod   |   соревнованиях
# международных ADJ ['Loc'] 	 amod   |   соревнованиях
# соревнованиях NOUN ['Loc'] 	 nmod   |   участия
# , PUNCT [] 	 punct   |   поддерживать
# поэтому ADV [] 	 advmod   |   поддерживать
# наша DET ['Nom'] 	 det   |   республика
# республика NOUN ['Nom'] 	 nsubj   |   поддерживать
# будет AUX [] 	 aux   |   поддерживать
# поддерживать VERB [] 	 conj   |   отстранены
# своих DET ['Acc'] 	 det   |   ребят
# ребят NOUN ['Acc'] 	 obj   |   поддерживать
# {'predicates': [{'action': ['отстранены', 'поддерживать'], 'subjects': [[{'item': 'республика', 'modifiers': []}]], 'objects': [[{'item': 'спортсмены', 'modifiers': [['российские', set()]]}], [{'item': 'ребят', 'modifiers': []}]]}], 'named entities': []}
# Спортсмены Коми наша гордость
# Спортсмены NOUN ['Nom'] 	 nsubj   |   гордость
# Коми PROPN ['Gen'] 	 nmod   |   Спортсмены
# наша DET ['Nom'] 	 det   |   гордость
# гордость NOUN ['Nom'] 	 ROOT   |   гордость
# {'predicates': [{'action': ['гордость'], 'subjects': [[{'item': 'Спортсмены', 'modifiers': [['Коми', set()]]}]], 'objects': []}], 'named entities': ['Коми']}
# Польша передала МВД Украины непригодные к эксплуатации вертолеты. 000
# Польша PROPN ['Nom'] 	 nsubj   |   передала
# передала VERB [] 	 ROOT   |   передала
# МВД PROPN ['Dat'] 	 iobj   |   передала
# Украины PROPN ['Gen'] 	 nmod   |   МВД
# непригодные ADJ ['Acc'] 	 amod   |   вертолеты
# к ADP [] 	 case   |   эксплуатации
# эксплуатации NOUN ['Dat'] 	 obl   |   непригодные
# вертолеты NOUN ['Acc'] 	 obj   |   передала
# . PUNCT [] 	 punct   |   передала
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['передала'], 'subjects': [[{'item': 'Польша', 'modifiers': []}]], 'objects': [[{'item': 'МВД', 'modifiers': [['Украины', set()]]}], [{'item': 'вертолеты', 'modifiers': [['непригодные', set()]]}]]}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['Польша', 'МВД Украины', 'Украины']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# Речь идёт о вертолётах МИ 8 и 412 , которые можно использовать только как запчасти для других единиц техники
# Речь NOUN ['Nom'] 	 nsubj   |   идёт
# идёт VERB [] 	 ROOT   |   идёт
# о ADP [] 	 case   |   вертолётах
# вертолётах NOUN ['Loc'] 	 obl   |   идёт
# МИ PROPN ['Nom'] 	 nmod   |   вертолётах
# 8 NUM [] 	 appos   |   МИ
# и CCONJ [] 	 cc   |   412
# 412 NUM [] 	 conj   |   МИ
# , PUNCT [] 	 punct   |   можно
# которые PRON ['Nom'] 	 nsubj   |   можно
# можно ADV [] 	 acl:relcl   |   вертолётах
# использовать VERB [] 	 csubj   |   можно
# только PART [] 	 advmod   |   запчасти
# как SCONJ [] 	 case   |   запчасти
# запчасти NOUN ['Acc'] 	 obj   |   использовать
# для ADP [] 	 case   |   единиц
# других ADJ ['Gen'] 	 amod   |   единиц
# единиц NOUN ['Gen'] 	 nmod   |   запчасти
# техники NOUN ['Gen'] 	 nmod   |   единиц
# {'predicates': [{'action': ['идёт'], 'subjects': [[{'item': 'Речь', 'modifiers': []}], [{'item': 'которые', 'modifiers': []}]], 'objects': [[{'item': 'запчасти', 'modifiers': [['только', set()], ['единиц', {'техники', 'других'}]]}]]}], 'named entities': ['412  МИ']}
# Об этом сообщает ТАСС со ссылкой на источники в российских силовых структурах. 000
# Об ADP [] 	 case   |   этом
# этом PRON ['Loc'] 	 obl   |   сообщает
# сообщает VERB [] 	 ROOT   |   сообщает
# ТАСС PROPN ['Nom'] 	 nsubj   |   сообщает
# со ADP [] 	 case   |   ссылкой
# ссылкой NOUN ['Ins'] 	 obl   |   сообщает
# на ADP [] 	 case   |   источники
# источники NOUN ['Acc'] 	 nmod   |   ссылкой
# в ADP [] 	 case   |   структурах
# российских ADJ ['Loc'] 	 amod   |   структурах
# силовых ADJ ['Loc'] 	 amod   |   структурах
# структурах NOUN ['Loc'] 	 nmod   |   источники
# . PUNCT [] 	 punct   |   сообщает
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['сообщает'], 'subjects': [[{'item': 'ТАСС', 'modifiers': []}]], 'objects': []}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['ТАСС']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# По его словам, отдавая Украине подобную технику, Варшава не только избавляется от хлама, но получает хорошую компенсацию от ЕС . 000
# По ADP [] 	 case   |   словам
# его DET [] 	 det   |   словам
# словам NOUN ['Dat'] 	 parataxis   |   избавляется
# , PUNCT [] 	 punct   |   словам
# отдавая VERB [] 	 advcl   |   избавляется
# Украине PROPN ['Dat'] 	 iobj   |   отдавая
# подобную ADJ ['Acc'] 	 amod   |   технику
# технику NOUN ['Acc'] 	 obj   |   отдавая
# , PUNCT [] 	 punct   |   отдавая
# Варшава PROPN ['Nom'] 	 nsubj   |   избавляется
# не PART [] 	 cc   |   избавляется
# только PART [] 	 fixed   |   не
# избавляется VERB [] 	 ROOT   |   избавляется
# от ADP [] 	 case   |   хлама
# хлама NOUN ['Gen'] 	 obl   |   избавляется
# , PUNCT [] 	 punct   |   получает
# но CCONJ [] 	 cc   |   получает
# получает VERB [] 	 conj   |   избавляется
# хорошую ADJ ['Acc'] 	 amod   |   компенсацию
# компенсацию NOUN ['Acc'] 	 obj   |   получает
# от ADP [] 	 case   |   ЕС
# ЕС PROPN ['Gen'] 	 nmod   |   компенсацию
# . PUNCT [] 	 punct   |   избавляется
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['избавляется', 'получает'], 'subjects': [[{'item': 'Варшава', 'modifiers': []}]], 'objects': [[{'item': 'Украине', 'modifiers': []}], [{'item': 'технику', 'modifiers': [['подобную', set()]]}], [{'item': 'компенсацию', 'modifiers': [['хорошую', set()], ['ЕС', set()]]}]]}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['Украине', 'Варшава', 'ЕС']}
# Вертолеты 412 были приняты на вооружение польских вооруженных сил в 1993 году, а затем, в 2011 м, переданы варшавской полиции
# Вертолеты NOUN ['Nom'] 	 nsubj:pass   |   приняты
# 412 NUM [] 	 appos   |   Вертолеты
# были AUX [] 	 aux:pass   |   приняты
# приняты VERB [] 	 ROOT   |   приняты
# на ADP [] 	 case   |   вооружение
# вооружение NOUN ['Acc'] 	 obl   |   приняты
# польских ADJ ['Gen'] 	 amod   |   сил
# вооруженных VERB ['Gen'] 	 amod   |   сил
# сил NOUN ['Gen'] 	 nmod   |   вооружение
# в ADP [] 	 case   |   году
# 1993 ADJ [] 	 amod   |   году
# году NOUN ['Loc'] 	 obl   |   приняты
# , PUNCT [] 	 punct   |   м
# а CCONJ [] 	 cc   |   м
# затем ADV [] 	 orphan   |   м
# , PUNCT [] 	 punct   |   2011
# в ADP [] 	 case   |   2011
# 2011 ADJ [] 	 amod   |   м
# м PROPN [] 	 conj   |   приняты
# , PUNCT [] 	 punct   |   переданы
# переданы VERB [] 	 conj   |   приняты
# варшавской ADJ ['Dat'] 	 amod   |   полиции
# полиции NOUN ['Dat'] 	 iobj   |   переданы
# {'predicates': [{'action': ['приняты', 'м', 'переданы'], 'subjects': [], 'objects': [[{'item': 'Вертолеты', 'modifiers': []}], [{'item': 'полиции', 'modifiers': [['варшавской', set()]]}]]}], 'named entities': ['м 2011']}
# Однако они находились в ангаре из за негодности к службе. 000
# Однако ADV [] 	 advmod   |   находились
# они PRON ['Nom'] 	 nsubj   |   находились
# находились VERB [] 	 ROOT   |   находились
# в ADP [] 	 case   |   ангаре
# ангаре NOUN ['Loc'] 	 obl   |   находились
# из ADP [] 	 case   |   негодности
# за ADP [] 	 case   |   негодности
# негодности NOUN ['Gen'] 	 obl   |   находились
# к ADP [] 	 case   |   службе
# службе NOUN ['Dat'] 	 nmod   |   негодности
# . PUNCT [] 	 punct   |   находились
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['находились'], 'subjects': [[{'item': 'они', 'modifiers': []}]], 'objects': []}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# Ранее замглавы министерства обороны страны Павел Залевский заявил, что Польша исчерпала почти все свои возможности военной помощи Украине
# Ранее ADV [] 	 advmod   |   заявил
# замглавы NOUN ['Nom'] 	 nsubj   |   заявил
# министерства NOUN ['Gen'] 	 nmod   |   замглавы
# обороны NOUN ['Gen'] 	 nmod   |   министерства
# страны NOUN ['Gen'] 	 nmod   |   министерства
# Павел PROPN ['Nom'] 	 appos   |   замглавы
# Залевский PROPN ['Nom'] 	 flat:name   |   Павел
# заявил VERB [] 	 ROOT   |   заявил
# , PUNCT [] 	 punct   |   исчерпала
# что SCONJ [] 	 mark   |   исчерпала
# Польша PROPN ['Nom'] 	 nsubj   |   исчерпала
# исчерпала VERB [] 	 ccomp   |   заявил
# почти ADV [] 	 advmod   |   все
# все DET ['Acc'] 	 det   |   возможности
# свои DET ['Acc'] 	 det   |   возможности
# возможности NOUN ['Acc'] 	 obj   |   исчерпала
# военной ADJ ['Gen'] 	 amod   |   помощи
# помощи NOUN ['Gen'] 	 nmod   |   возможности
# Украине PROPN ['Dat'] 	 iobj   |   исчерпала
# {'predicates': [{'action': ['заявил'], 'subjects': [[{'item': 'замглавы', 'modifiers': [['министерства', {'обороны', 'страны'}]]}], [{'item': 'Польша', 'modifiers': []}]], 'objects': [[{'item': 'возможности', 'modifiers': [['помощи', {'военной'}]]}], [{'item': 'Украине', 'modifiers': []}]]}], 'named entities': ['Павел', 'Залевский', 'Польша', 'Украине']}
# Кроме того, он опроверг сообщения о том, что Варшава может в ближайшее время передать Украине запрошенные ранее истребители МиГ 29
# Кроме ADP [] 	 case   |   того
# того PRON ['Gen'] 	 parataxis   |   опроверг
# , PUNCT [] 	 punct   |   того
# он PRON ['Nom'] 	 nsubj   |   опроверг
# опроверг VERB [] 	 ROOT   |   опроверг
# сообщения NOUN ['Acc'] 	 obj   |   опроверг
# о ADP [] 	 case   |   том
# том PRON ['Loc'] 	 nmod   |   сообщения
# , PUNCT [] 	 punct   |   может
# что SCONJ [] 	 mark   |   может
# Варшава PROPN ['Nom'] 	 nsubj   |   может
# может VERB [] 	 acl   |   том
# в ADP [] 	 case   |   время
# ближайшее ADJ ['Acc'] 	 amod   |   время
# время NOUN ['Acc'] 	 obl   |   передать
# передать VERB [] 	 xcomp   |   может
# Украине PROPN ['Dat'] 	 iobj   |   передать
# запрошенные VERB ['Acc'] 	 acl   |   истребители
# ранее ADV [] 	 advmod   |   запрошенные
# истребители NOUN ['Nom'] 	 obj   |   передать
# МиГ PROPN ['Nom'] 	 appos   |   истребители
# 29 NUM [] 	 punct   |   опроверг
# {'predicates': [{'action': ['опроверг'], 'subjects': [[{'item': 'он', 'modifiers': []}], [{'item': 'Варшава', 'modifiers': []}]], 'objects': [[{'item': 'сообщения', 'modifiers': [['том', set()]]}], [{'item': 'Украине', 'modifiers': []}], [{'item': 'истребители', 'modifiers': []}]]}], 'named entities': ['Варшава', 'Украине', 'МиГ']}
# О невозможности передать данную технику также говорил и премьер министр страны Дональд Туск.
# О ADP [] 	 case   |   невозможности
# невозможности NOUN ['Loc'] 	 obl   |   говорил
# передать VERB [] 	 nmod   |   невозможности
# данную ADJ ['Acc'] 	 amod   |   технику
# технику NOUN ['Acc'] 	 obj   |   передать
# также ADV [] 	 advmod   |   говорил
# говорил VERB [] 	 ROOT   |   говорил
# и PART [] 	 advmod   |   премьер
# премьер NOUN ['Nom'] 	 nsubj   |   говорил
# министр NOUN ['Nom'] 	 nsubj   |   говорил
# страны NOUN ['Gen'] 	 nmod   |   министр
# Дональд PROPN ['Nom'] 	 appos   |   министр
# Туск PROPN ['Nom'] 	 flat:name   |   Дональд
# . PUNCT [] 	 punct   |   говорил
# {'predicates': [{'action': ['говорил'], 'subjects': [[{'item': 'премьер', 'modifiers': [['и', set()]]}], [{'item': 'министр', 'modifiers': [['страны', set()]]}]], 'objects': [[{'item': 'технику', 'modifiers': [['данную', set()]]}]]}], 'named entities': ['Дональд', 'Туск']}
#  Во всех муниципалитетах Коми создадут оперативные штабы на период новогодних праздников 000
#   SPACE [] 	 dep   |   Во
# Во ADP [] 	 case   |   муниципалитетах
# всех DET ['Loc'] 	 det   |   муниципалитетах
# муниципалитетах NOUN ['Loc'] 	 obl   |   создадут
# Коми PROPN ['Nom'] 	 nsubj   |   создадут
# создадут VERB [] 	 ROOT   |   создадут
# оперативные ADJ ['Acc'] 	 amod   |   штабы
# штабы NOUN ['Acc'] 	 obj   |   создадут
# на ADP [] 	 case   |   период
# период NOUN ['Acc'] 	 obl   |   создадут
# новогодних ADJ ['Gen'] 	 amod   |   праздников
# праздников NOUN ['Gen'] 	 nmod   |   период
# 000 NUM [] 	 punct   |   создадут
# {'predicates': [{'action': ['создадут'], 'subjects': [[{'item': 'Коми', 'modifiers': []}]], 'objects': [[{'item': 'штабы', 'modifiers': [['оперативные', set()]]}]]}], 'named entities': ['Коми']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# Такое поручение дал врио главы республики Ростислав Гольдштейн
# Такое DET ['Acc'] 	 det   |   поручение
# поручение NOUN ['Acc'] 	 obj   |   дал
# дал VERB [] 	 ROOT   |   дал
# врио NOUN ['Nom'] 	 nsubj   |   дал
# главы NOUN ['Gen'] 	 nmod   |   врио
# республики NOUN ['Gen'] 	 nmod   |   главы
# Ростислав PROPN ['Nom'] 	 appos   |   врио
# Гольдштейн PROPN ['Nom'] 	 flat:name   |   Ростислав
# {'predicates': [{'action': ['дал'], 'subjects': [[{'item': 'врио', 'modifiers': [['главы', {'республики'}]]}]], 'objects': [[{'item': 'поручение', 'modifiers': []}]]}], 'named entities': ['Ростислав', 'Гольдштейн']}
# Он поручил главам муниципальных образований контролировать всё, что касается пожарной безопасности, мест массового отдыха и круглосуточного пребывания людей, а также разобраться с проблемой работы ЕДДС. 000
# Он PRON ['Nom'] 	 nsubj   |   поручил
# поручил VERB [] 	 ROOT   |   поручил
# главам NOUN ['Dat'] 	 iobj   |   поручил
# муниципальных ADJ ['Gen'] 	 amod   |   образований
# образований NOUN ['Gen'] 	 nmod   |   главам
# контролировать VERB [] 	 xcomp   |   поручил
# всё PRON ['Acc'] 	 obj   |   контролировать
# , PUNCT [] 	 punct   |   касается
# что PRON ['Nom'] 	 nsubj   |   касается
# касается VERB [] 	 acl:relcl   |   всё
# пожарной ADJ ['Gen'] 	 amod   |   безопасности
# безопасности NOUN ['Gen'] 	 obj   |   касается
# , PUNCT [] 	 punct   |   мест
# мест NOUN ['Gen'] 	 conj   |   безопасности
# массового ADJ ['Gen'] 	 amod   |   отдыха
# отдыха NOUN ['Gen'] 	 nmod   |   мест
# и CCONJ [] 	 cc   |   пребывания
# круглосуточного ADJ ['Gen'] 	 amod   |   пребывания
# пребывания NOUN ['Gen'] 	 conj   |   отдыха
# людей NOUN ['Gen'] 	 nmod   |   пребывания
# , PUNCT [] 	 punct   |   разобраться
# а CCONJ [] 	 cc   |   разобраться
# также ADV [] 	 fixed   |   а
# разобраться VERB [] 	 conj   |   касается
# с ADP [] 	 case   |   проблемой
# проблемой NOUN ['Ins'] 	 obl   |   разобраться
# работы NOUN ['Gen'] 	 nmod   |   проблемой
# ЕДДС PROPN ['Gen'] 	 nmod   |   работы
# . PUNCT [] 	 punct   |   поручил
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['поручил', 'контролировать'], 'subjects': [[{'item': 'Он', 'modifiers': []}], [{'item': 'что', 'modifiers': []}]], 'objects': [[{'item': 'главам', 'modifiers': [['образований', {'муниципальных'}]]}], [{'item': 'всё', 'modifiers': []}], [{'item': 'мест', 'modifiers': [['отдыха', {'массового'}]]}, {'item': 'безопасности', 'modifiers': [['пожарной', set()]]}]]}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['ЕДДС']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# На территориях оперштабы призваны организовать стабильную работу систем жизнеобеспечения и информировать жителей о принятых мерах при нештатных ситуациях. 000
# На ADP [] 	 case   |   территориях
# территориях NOUN ['Loc'] 	 obl   |   призваны
# оперштабы NOUN ['Nom'] 	 nsubj   |   призваны
# призваны ADJ [] 	 ROOT   |   призваны
# организовать VERB [] 	 xcomp   |   призваны
# стабильную ADJ ['Acc'] 	 amod   |   работу
# работу NOUN ['Acc'] 	 obj   |   организовать
# систем NOUN ['Gen'] 	 nmod   |   работу
# жизнеобеспечения NOUN ['Gen'] 	 nmod   |   систем
# и CCONJ [] 	 cc   |   информировать
# информировать VERB [] 	 conj   |   организовать
# жителей NOUN ['Acc'] 	 obj   |   информировать
# о ADP [] 	 case   |   мерах
# принятых VERB ['Loc'] 	 amod   |   мерах
# мерах NOUN ['Loc'] 	 obl   |   информировать
# при ADP [] 	 case   |   ситуациях
# нештатных ADJ ['Loc'] 	 amod   |   ситуациях
# ситуациях NOUN ['Loc'] 	 nmod   |   мерах
# . PUNCT [] 	 punct   |   призваны
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['призваны', 'организовать'], 'subjects': [[{'item': 'оперштабы', 'modifiers': []}]], 'objects': [[{'item': 'работу', 'modifiers': [['стабильную', set()], ['систем', {'жизнеобеспечения'}]]}], [{'item': 'жителей', 'modifiers': []}]]}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# Номер ЕДДС Инты (82145) 6 84 15.
# Номер NOUN ['Nom'] 	 nsubj   |   15
# ЕДДС PROPN ['Gen'] 	 nmod   |   Номер
# Инты PROPN ['Gen'] 	 appos   |   Номер
# ( PUNCT [] 	 punct   |   82145
# 82145 ADJ [] 	 nummod   |   Номер
# ) PUNCT [] 	 punct   |   82145
# 6 NUM [] 	 nummod   |   15
# 84 NUM [] 	 flat   |   6
# 15 NUM [] 	 ROOT   |   15
# . PUNCT [] 	 punct   |   15
# {'predicates': [{'action': ['15'], 'subjects': [[{'item': 'Номер', 'modifiers': [['ЕДДС', set()]]}]], 'objects': []}], 'named entities': ['ЕДДС', 'Инты']}
#  С января в Республике Коми начнёт действовать региональная программа подготовки управленцев из числа участников СВО 000
#   SPACE [] 	 dep   |   С
# С ADP [] 	 case   |   января
# января NOUN ['Gen'] 	 obl   |   начнёт
# в ADP [] 	 case   |   Республике
# Республике PROPN ['Loc'] 	 obl   |   начнёт
# Коми PROPN ['Nom'] 	 appos   |   Республике
# начнёт ADV [] 	 ROOT   |   начнёт
# действовать VERB [] 	 xcomp   |   начнёт
# региональная ADJ ['Nom'] 	 amod   |   программа
# программа NOUN ['Nom'] 	 nsubj   |   начнёт
# подготовки NOUN ['Gen'] 	 nmod   |   программа
# управленцев NOUN ['Gen'] 	 nmod   |   подготовки
# из ADP [] 	 case   |   числа
# числа NOUN ['Gen'] 	 nmod   |   подготовки
# участников NOUN ['Gen'] 	 nmod   |   числа
# СВО PROPN ['Gen'] 	 nmod   |   участников
# 000 NUM [] 	 punct   |   начнёт
# {'predicates': [{'action': ['начнёт', 'действовать'], 'subjects': [[{'item': 'программа', 'modifiers': [['региональная', set()], ['подготовки', {'числа', 'СВО', 'управленцев', 'участников'}]]}]], 'objects': []}], 'named entities': ['Республике', 'Коми', 'СВО']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# Об этом заявил врио Главы Коми [ 889423310 Ростислав Гольдштейн] во время прямого эфира
# Об ADP [] 	 case   |   этом
# этом PRON ['Loc'] 	 obl   |   заявил
# заявил VERB [] 	 ROOT   |   заявил
# врио NOUN ['Nom'] 	 nsubj   |   заявил
# Главы PROPN ['Gen'] 	 nmod   |   врио
# Коми PROPN ['Gen'] 	 nmod   |   Главы
# [ PUNCT [] 	 punct   |   889423310
# 889423310 NUM [] 	 appos   |   врио
# Ростислав PROPN ['Nom'] 	 appos   |   врио
# Гольдштейн PROPN ['Nom'] 	 flat:name   |   Ростислав
# ] PUNCT [] 	 punct   |   Ростислав
# во ADP [] 	 case   |   эфира
# время NOUN ['Acc'] 	 fixed   |   во
# прямого ADJ ['Gen'] 	 amod   |   эфира
# эфира NOUN ['Gen'] 	 obl   |   заявил
# {'predicates': [{'action': ['заявил'], 'subjects': [[{'item': 'врио', 'modifiers': [['Главы', {'Коми'}]]}]], 'objects': []}], 'named entities': ['Главы Коми', 'Коми', 'Ростислав', 'Гольдштейн']}
# По его словам, региональный проект даст возможность ветеранам спецоперации проявить себя и принести пользу землякам на госслужбе
# По ADP [] 	 case   |   словам
# его DET [] 	 det   |   словам
# словам NOUN ['Dat'] 	 parataxis   |   даст
# , PUNCT [] 	 punct   |   словам
# региональный ADJ ['Nom'] 	 amod   |   проект
# проект NOUN ['Nom'] 	 nsubj   |   даст
# даст VERB [] 	 ROOT   |   даст
# возможность NOUN ['Acc'] 	 obj   |   даст
# ветеранам NOUN ['Dat'] 	 iobj   |   возможность
# спецоперации NOUN ['Gen'] 	 nmod   |   ветеранам
# проявить VERB [] 	 nmod   |   возможность
# себя PRON ['Acc'] 	 obj   |   проявить
# и CCONJ [] 	 cc   |   принести
# принести VERB [] 	 conj   |   проявить
# пользу NOUN ['Acc'] 	 obj   |   принести
# землякам NOUN ['Dat'] 	 iobj   |   принести
# на ADP [] 	 case   |   госслужбе
# госслужбе NOUN ['Loc'] 	 nmod   |   землякам
# {'predicates': [{'action': ['даст'], 'subjects': [[{'item': 'проект', 'modifiers': [['региональный', set()]]}]], 'objects': [[{'item': 'возможность', 'modifiers': [['проявить', set()]]}], [{'item': 'ветеранам', 'modifiers': [['спецоперации', set()]]}], [{'item': 'себя', 'modifiers': []}], [{'item': 'пользу', 'modifiers': []}], [{'item': 'землякам', 'modifiers': [['госслужбе', set()]]}]]}], 'named entities': []}
# Участниками программы смогут стать как ветераны, так и действующие бойцы. 000
# Участниками NOUN ['Ins'] 	 xcomp   |   смогут
# программы NOUN ['Gen'] 	 nmod   |   Участниками
# смогут VERB [] 	 ROOT   |   смогут
# стать VERB [] 	 xcomp   |   смогут
# как SCONJ [] 	 case   |   ветераны
# ветераны NOUN ['Nom'] 	 obl   |   стать
# , PUNCT [] 	 punct   |   бойцы
# так ADV [] 	 cc   |   бойцы
# и PART [] 	 fixed   |   так
# действующие VERB ['Nom'] 	 amod   |   бойцы
# бойцы NOUN ['Nom'] 	 conj   |   ветераны
# . PUNCT [] 	 punct   |   смогут
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['смогут', 'Участниками', 'стать'], 'subjects': [], 'objects': []}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# Профпереподготовка будет включать образовательный цикл по направлению Государственное и муниципальное управление , стажировку в органах власти, навыки командной работы и личностный рост. 000
# Профпереподготовка NOUN ['Nom'] 	 nsubj   |   включать
# будет AUX [] 	 aux   |   включать
# включать VERB [] 	 ROOT   |   включать
# образовательный ADJ ['Acc'] 	 amod   |   цикл
# цикл NOUN ['Acc'] 	 obj   |   включать
# по ADP [] 	 case   |   направлению
# направлению NOUN ['Dat'] 	 nmod   |   цикл
# Государственное PROPN ['Nom'] 	 amod   |   управление
# и CCONJ [] 	 cc   |   муниципальное
# муниципальное ADJ ['Nom'] 	 conj   |   Государственное
# управление NOUN ['Nom'] 	 obj   |   включать
# , PUNCT [] 	 punct   |   стажировку
# стажировку NOUN ['Acc'] 	 conj   |   управление
# в ADP [] 	 case   |   органах
# органах NOUN ['Loc'] 	 nmod   |   стажировку
# власти NOUN ['Gen'] 	 nmod   |   органах
# , PUNCT [] 	 punct   |   навыки
# навыки NOUN ['Nom'] 	 conj   |   управление
# командной ADJ ['Gen'] 	 amod   |   работы
# работы NOUN ['Gen'] 	 nmod   |   навыки
# и CCONJ [] 	 cc   |   рост
# личностный ADJ ['Acc'] 	 amod   |   рост
# рост NOUN ['Acc'] 	 conj   |   управление
# . PUNCT [] 	 punct   |   включать
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['включать'], 'subjects': [[{'item': 'Профпереподготовка', 'modifiers': []}]], 'objects': [[{'item': 'цикл', 'modifiers': [['образовательный', set()], ['направлению', set()]]}], [{'item': 'стажировку', 'modifiers': [['органах', {'власти'}]]}, {'item': 'навыки', 'modifiers': [['работы', {'командной'}]]}, {'item': 'рост', 'modifiers': [['личностный', set()]]}, {'item': 'управление', 'modifiers': [['Государственное', set()]]}]]}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['муниципальное  Государственное']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
#  Жителям Коми предлагается самим выбрать название региональной программы
#   SPACE [] 	 dep   |   Жителям
# Жителям NOUN ['Dat'] 	 iobj   |   предлагается
# Коми PROPN ['Gen'] 	 nmod   |   Жителям
# предлагается VERB [] 	 ROOT   |   предлагается
# самим ADJ ['Dat'] 	 cop   |   предлагается
# выбрать VERB [] 	 csubj:pass   |   предлагается
# название NOUN ['Acc'] 	 obj   |   выбрать
# региональной ADJ ['Gen'] 	 amod   |   программы
# программы NOUN ['Gen'] 	 nmod   |   название
# {'predicates': [{'action': ['предлагается', 'выбрать'], 'subjects': [], 'objects': [[{'item': 'Жителям', 'modifiers': [['Коми', set()]]}], [{'item': 'название', 'modifiers': [['программы', {'региональной'}]]}]]}], 'named entities': ['Коми']}
# Для этого нужно: 000
# Для ADP [] 	 case   |   этого
# этого PRON ['Gen'] 	 obl   |   нужно
# нужно ADJ [] 	 ROOT   |   нужно
# : PUNCT [] 	 punct   |   нужно
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['нужно'], 'subjects': [], 'objects': []}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
#  оставить свой вариант названия в комментариях под [ : . 100347671 10836 постом Общественной палаты Коми], 000
#   SPACE [] 	 dep   |
# оставить VERB [] 	 ROOT   |   оставить
# свой DET ['Acc'] 	 det   |   вариант
# вариант NOUN ['Acc'] 	 obj   |   оставить
# названия NOUN ['Gen'] 	 nmod   |   вариант
# в ADP [] 	 case   |   комментариях
# комментариях NOUN ['Loc'] 	 nmod   |   названия
# под ADP [] 	 advmod   |   оставить
# [ PUNCT [] 	 punct   |   :
# : PUNCT [] 	 punct   |   под
# . PUNCT [] 	 punct   |   оставить
# 100347671 ADJ [] 	 amod   |   10836
# 10836 ADJ [] 	 ROOT   |   10836
# постом NOUN ['Ins'] 	 ROOT   |   постом
# Общественной ADJ ['Gen'] 	 amod   |   палаты
# палаты NOUN ['Gen'] 	 nmod   |   постом
# Коми PROPN ['Gen'] 	 nmod   |   палаты
# ] PUNCT [] 	 punct   |   постом
# , PUNCT [] 	 punct   |   постом
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['оставить'], 'subjects': [], 'objects': [[{'item': 'вариант', 'modifiers': [['названия', {'комментариях'}]]}]]}, {'action': ['10836'], 'subjects': [], 'objects': []}, {'action': ['постом'], 'subjects': [], 'objects': []}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['Коми']}
#  после 28 декабря в [ 100347671 паблике Общественной палаты] проголосовать за лучший вариант названия.
#   SPACE [] 	 dep   |
# после ADP [] 	 case   |   28
# 28 ADJ [] 	 obl   |   проголосовать
# декабря NOUN ['Gen'] 	 flat   |   28
# в ADP [] 	 case   |   паблике
# [ PUNCT [] 	 punct   |   паблике
# 100347671 NUM [] 	 amod   |   паблике
# паблике NOUN ['Loc'] 	 obl   |   проголосовать
# Общественной ADJ ['Gen'] 	 amod   |   палаты
# палаты NOUN ['Gen'] 	 nmod   |   паблике
# ] PUNCT [] 	 punct   |   паблике
# проголосовать VERB [] 	 ROOT   |   проголосовать
# за ADP [] 	 case   |   вариант
# ...
# недавно ADV [] 	 advmod   |   заявил
# заявил VERB [] 	 ROOT   |   заявил
# президент NOUN ['Nom'] 	 nsubj   |   заявил
# Владимир PROPN ['Nom'] 	 appos   |   президент
# Зеленский PROPN ['Nom'] 	 flat:name   |   Владимир
# , PUNCT [] 	 punct   |   окрестили
# поэтому ADV [] 	 advmod   |   окрестили
# обещанную VERB ['Acc'] 	 amod   |   помощь
# помощь NOUN ['Acc'] 	 obj   |   окрестили
# украинцы NOUN ['Nom'] 	 nsubj   |   окрестили
# уже ADV [] 	 advmod   |   окрестили
# окрестили VERB [] 	 conj   |   заявил
# Вовиной ADJ ['Ins'] 	 xcomp   |   окрестили
# тысячей NOUN ['Ins'] 	 obl   |   окрестили
# {'predicates': [{'action': ['заявил', 'окрестили'], 'subjects': [[{'item': 'президент', 'modifiers': []}], [{'item': 'украинцы', 'modifiers': []}]], 'objects': [[{'item': 'помощь', 'modifiers': [['обещанную', set()]]}]]}], 'named entities': ['Владимир', 'Зеленский']}
# Но есть еще один нюанс, чтобы получить деньги необходимо оформить карту Украинский кэшбек и дать разрешение на обработку банком информации по вашим счетам
# Но CCONJ [] 	 cc   |   есть
# есть VERB [] 	 ROOT   |   есть
# еще ADV [] 	 advmod   |   один
# один NUM ['Nom'] 	 nummod   |   нюанс
# нюанс NOUN ['Nom'] 	 nsubj   |   есть
# , PUNCT [] 	 punct   |   получить
# чтобы SCONJ [] 	 mark   |   получить
# получить VERB [] 	 csubj   |   необходимо
# деньги NOUN ['Acc'] 	 obj   |   получить
# необходимо ADJ [] 	 conj   |   есть
# оформить VERB [] 	 csubj   |   необходимо
# карту NOUN ['Acc'] 	 obj   |   оформить
# Украинский ADJ ['Nom'] 	 amod   |   кэшбек
# кэшбек NOUN ['Acc'] 	 obj   |   оформить
# и CCONJ [] 	 cc   |   дать
# дать VERB [] 	 conj   |   оформить
# разрешение NOUN ['Acc'] 	 obj   |   дать
# на ADP [] 	 case   |   обработку
# обработку NOUN ['Acc'] 	 nmod   |   разрешение
# банком NOUN ['Ins'] 	 nmod   |   обработку
# информации NOUN ['Gen'] 	 nmod   |   банком
# по ADP [] 	 case   |   счетам
# вашим DET ['Dat'] 	 det   |   счетам
# счетам NOUN ['Dat'] 	 nmod   |   информации
# {'predicates': [{'action': ['есть', 'необходимо'], 'subjects': [[{'item': 'нюанс', 'modifiers': []}]], 'objects': [[{'item': 'деньги', 'modifiers': []}], [{'item': 'карту', 'modifiers': []}], [{'item': 'кэшбек', 'modifiers': [['Украинский', set()]]}], [{'item': 'разрешение', 'modifiers': [['обработку', {'информации', 'банком', 'счетам'}]]}]]}], 'named entities': []}
#  Вовина тысяча это попытка выявить уклонистов, заявила замглавы налогового комитета Ольга Василевская Смаглюк (партия Слуга народа ). 000
#   SPACE [] 	 dep   |   Вовина
# Вовина PROPN ['Nom'] 	 nsubj   |   попытка
# тысяча NOUN ['Nom'] 	 case   |   Вовина
# это PRON ['Nom'] 	 nsubj   |   попытка
# попытка NOUN ['Nom'] 	 ROOT   |   попытка
# выявить VERB [] 	 nmod   |   попытка
# уклонистов NOUN ['Acc'] 	 obj   |   выявить
# , PUNCT [] 	 punct   |   заявила
# заявила VERB [] 	 parataxis   |   попытка
# замглавы NOUN ['Nom'] 	 nsubj   |   заявила
# налогового ADJ ['Gen'] 	 amod   |   комитета
# комитета NOUN ['Gen'] 	 nmod   |   замглавы
# Ольга PROPN ['Nom'] 	 appos   |   замглавы
# Василевская ADJ ['Nom'] 	 flat:name   |   Ольга
# Смаглюк PROPN ['Nom'] 	 flat:name   |   Ольга
# ( PUNCT [] 	 punct   |   партия
# партия NOUN ['Nom'] 	 parataxis   |   Ольга
# Слуга PROPN ['Gen'] 	 nmod   |   партия
# народа NOUN ['Gen'] 	 nmod   |   Слуга
# ) PUNCT [] 	 punct   |   партия
# . PUNCT [] 	 punct   |   попытка
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['попытка'], 'subjects': [[{'item': 'Вовина', 'modifiers': []}], [{'item': 'это', 'modifiers': []}], [{'item': 'замглавы', 'modifiers': [['комитета', {'налогового'}]]}]], 'objects': [[{'item': 'уклонистов', 'modifiers': []}]]}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['Вовина', 'Ольга', 'Смаглюк', 'Слуга народа']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# Получается, что Украина настолько заботится о своих гражданах, что даже для пополнения рядов армии разработали поистине гениальную стратегию по выявлению уклонистов под прикрытием социальной программы. 000
# Получается VERB [] 	 ROOT   |   Получается
# , PUNCT [] 	 punct   |   заботится
# что SCONJ [] 	 mark   |   заботится
# Украина PROPN ['Nom'] 	 nsubj   |   заботится
# настолько ADV [] 	 advmod   |   заботится
# заботится VERB [] 	 ccomp   |   Получается
# о ADP [] 	 case   |   гражданах
# своих DET ['Loc'] 	 det   |   гражданах
# гражданах NOUN ['Loc'] 	 obl   |   заботится
# , PUNCT [] 	 punct   |   разработали
# что SCONJ [] 	 mark   |   разработали
# даже PART [] 	 advmod   |   пополнения
# для ADP [] 	 case   |   пополнения
# пополнения NOUN ['Gen'] 	 obl   |   разработали
# рядов NOUN ['Gen'] 	 nmod   |   пополнения
# армии NOUN ['Gen'] 	 nmod   |   пополнения
# разработали VERB [] 	 parataxis   |   заботится
# поистине ADV [] 	 advmod   |   гениальную
# гениальную ADJ ['Acc'] 	 amod   |   стратегию
# стратегию NOUN ['Acc'] 	 obj   |   разработали
# по ADP [] 	 case   |   выявлению
# выявлению NOUN ['Dat'] 	 nmod   |   стратегию
# уклонистов NOUN ['Gen'] 	 nmod   |   выявлению
# под ADP [] 	 case   |   прикрытием
# прикрытием NOUN ['Ins'] 	 nmod   |   выявлению
# социальной ADJ ['Gen'] 	 amod   |   программы
# программы NOUN ['Gen'] 	 nmod   |   прикрытием
# . PUNCT [] 	 punct   |   Получается
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['Получается'], 'subjects': [[{'item': 'Украина', 'modifiers': []}]], 'objects': [[{'item': 'стратегию', 'modifiers': [['гениальную', {'поистине'}], ['выявлению', {'прикрытием', 'уклонистов', 'социальной', 'программы'}]]}]]}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['Украина']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# В то время как одни считают, что сумма слишком мала, чтобы кого то мотивировать, власти уже не скрывают своих надежд на то, что традиционная для некоторых категорий украинцев жажда наживы пересилит здравый смысл
# В ADP [] 	 cc   |   считают
# то DET ['Acc'] 	 fixed   |   В
# время NOUN ['Acc'] 	 fixed   |   В
# как SCONJ [] 	 fixed   |   В
# одни DET ['Nom'] 	 nsubj   |   считают
# считают VERB [] 	 ROOT   |   считают
# , PUNCT [] 	 punct   |   мала
# что SCONJ [] 	 mark   |   мала
# сумма NOUN ['Nom'] 	 nsubj   |   мала
# слишком ADV [] 	 advmod   |   мала
# мала ADJ [] 	 ccomp   |   считают
# , PUNCT [] 	 punct   |   мотивировать
# чтобы SCONJ [] 	 mark   |   мотивировать
# кого PRON ['Acc'] 	 obj   |   мотивировать
# то PRON ['Acc'] 	 obj   |   мотивировать
# мотивировать VERB [] 	 advcl   |   скрывают
# , PUNCT [] 	 punct   |   мотивировать
# власти NOUN ['Nom'] 	 nsubj   |   скрывают
# уже ADV [] 	 advmod   |   скрывают
# не PART [] 	 advmod   |   скрывают
# скрывают VERB [] 	 conj   |   мала
# своих DET ['Gen'] 	 det   |   надежд
# надежд NOUN ['Gen'] 	 obj   |   скрывают
# на ADP [] 	 case   |   то
# то PRON ['Acc'] 	 obl   |   скрывают
# , PUNCT [] 	 punct   |   пересилит
# что SCONJ [] 	 mark   |   пересилит
# традиционная ADJ ['Nom'] 	 amod   |   жажда
# для ADP [] 	 case   |   категорий
# некоторых DET ['Gen'] 	 det   |   категорий
# категорий NOUN ['Gen'] 	 nmod   |   традиционная
# украинцев NOUN ['Gen'] 	 nmod   |   категорий
# жажда NOUN ['Nom'] 	 nsubj   |   пересилит
# наживы NOUN ['Gen'] 	 nmod   |   жажда
# пересилит VERB [] 	 acl   |   то
# здравый ADJ ['Nom'] 	 amod   |   смысл
# смысл NOUN ['Nom'] 	 obj   |   пересилит
# {'predicates': [{'action': ['считают'], 'subjects': [[{'item': 'одни', 'modifiers': []}], [{'item': 'сумма', 'modifiers': []}], [{'item': 'власти', 'modifiers': []}], [{'item': 'жажда', 'modifiers': [['традиционная', {'украинцев', 'категорий'}], ['наживы', set()]]}]], 'objects': [[{'item': 'кого', 'modifiers': []}], [{'item': 'то', 'modifiers': []}], [{'item': 'надежд', 'modifiers': []}], [{'item': 'смысл', 'modifiers': [['здравый', set()]]}]]}], 'named entities': []}
# Тысяча гривен за регистрацию и бесплатная путёвка на передовую настоящий для украинских патриотов и целая тысяча поводов стать героем, правда, посмертно
# Тысяча NOUN ['Nom'] 	 nummod:gov   |   гривен
# гривен NOUN ['Gen'] 	 ROOT   |   гривен
# за ADP [] 	 case   |   регистрацию
# регистрацию NOUN ['Acc'] 	 nmod   |   гривен
# и CCONJ [] 	 cc   |   путёвка
# бесплатная ADJ ['Nom'] 	 amod   |   путёвка
# путёвка NOUN ['Nom'] 	 conj   |   регистрацию
# на ADP [] 	 case   |   поводов
# передовую ADJ ['Acc'] 	 amod   |   поводов
# настоящий ADJ ['Acc'] 	 amod   |   поводов
# для ADP [] 	 case   |   патриотов
# украинских ADJ ['Gen'] 	 amod   |   патриотов
# патриотов NOUN ['Gen'] 	 obl   |   настоящий
# и CCONJ [] 	 cc   |   поводов
# целая ADJ ['Nom'] 	 amod   |   тысяча
# тысяча NOUN ['Nom'] 	 nummod:gov   |   поводов
# поводов NOUN ['Gen'] 	 nmod   |   путёвка
# стать VERB [] 	 nmod   |   гривен
# героем NOUN ['Ins'] 	 xcomp   |   стать
# , PUNCT [] 	 punct   |   правда
# правда ADV [] 	 case   |   гривен
# , PUNCT [] 	 punct   |   правда
# посмертно ADV [] 	 ROOT   |   посмертно
# {'predicates': [{'action': ['гривен'], 'subjects': [], 'objects': []}, {'action': ['посмертно'], 'subjects': [], 'objects': []}], 'named entities': []}
#  Война до последнего украинца , похоже, теперь имеет свой спонсорский пакет.
#   SPACE [] 	 dep   |   Война
# Война NOUN ['Nom'] 	 nsubj   |   имеет
# до ADP [] 	 case   |   украинца
# последнего ADJ ['Gen'] 	 amod   |   украинца
# украинца NOUN ['Gen'] 	 nmod   |   Война
# , PUNCT [] 	 punct   |   похоже
# похоже ADV [] 	 parataxis   |   имеет
# , PUNCT [] 	 punct   |   похоже
# теперь ADV [] 	 advmod   |   имеет
# имеет VERB [] 	 ROOT   |   имеет
# свой DET ['Acc'] 	 det   |   пакет
# спонсорский ADJ ['Acc'] 	 amod   |   пакет
# пакет NOUN ['Acc'] 	 obj   |   имеет
# . PUNCT [] 	 punct   |   имеет
# {'predicates': [{'action': ['имеет'], 'subjects': [[{'item': 'Война', 'modifiers': [['украинца', {'последнего'}]]}]], 'objects': [[{'item': 'пакет', 'modifiers': [['спонсорский', set()]]}]]}], 'named entities': []}
# В Коми заработал Военно социальный центр 000
# В ADP [] 	 case   |   Коми
# Коми PROPN ['Loc'] 	 obl   |   заработал
# заработал VERB [] 	 ROOT   |   заработал
# Военно ADV [] 	 advmod   |   социальный
# социальный ADJ ['Acc'] 	 amod   |   центр
# центр NOUN ['Acc'] 	 nsubj   |   заработал
# 000 NUM [] 	 appos   |   центр
# {'predicates': [{'action': ['заработал'], 'subjects': [[{'item': 'центр', 'modifiers': [['социальный', {'Военно'}]]}]], 'objects': []}], 'named entities': ['Коми']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# Центр создан Министерством обороны РФ и будет работать как МФЦ
# Центр NOUN ['Nom'] 	 nsubj:pass   |   создан
# создан VERB [] 	 ROOT   |   создан
# Министерством PROPN ['Ins'] 	 obl:agent   |   создан
# обороны NOUN ['Gen'] 	 nmod   |   Министерством
# РФ PROPN ['Gen'] 	 nmod   |   обороны
# и CCONJ [] 	 cc   |   работать
# будет AUX [] 	 aux   |   работать
# работать VERB [] 	 conj   |   создан
# как SCONJ [] 	 case   |   МФЦ
# МФЦ PROPN ['Nom'] 	 obl   |   работать
# {'predicates': [{'action': ['создан', 'работать'], 'subjects': [], 'objects': [[{'item': 'Центр', 'modifiers': []}]]}], 'named entities': ['Министерством обороны РФ', 'РФ', 'МФЦ']}
# Действующие и уходящие в запас военные, а также их семьи смогут обратиться и получить необходимые справки в режиме одного окна
# Действующие VERB ['Nom'] 	 acl   |   военные
# и CCONJ [] 	 cc   |   уходящие
# уходящие VERB ['Nom'] 	 conj   |   Действующие
# в ADP [] 	 case   |   запас
# запас NOUN ['Acc'] 	 obl   |   уходящие
# военные NOUN ['Nom'] 	 nsubj   |   смогут
# , PUNCT [] 	 punct   |   семьи
# а CCONJ [] 	 cc   |   семьи
# также ADV [] 	 fixed   |   а
# их DET [] 	 det   |   семьи
# семьи NOUN ['Nom'] 	 nsubj   |   смогут
# смогут VERB [] 	 ROOT   |   смогут
# обратиться VERB [] 	 xcomp   |   смогут
# и CCONJ [] 	 cc   |   получить
# получить VERB [] 	 conj   |   обратиться
# необходимые ADJ ['Acc'] 	 amod   |   справки
# справки NOUN ['Acc'] 	 obj   |   получить
# в ADP [] 	 case   |   режиме
# режиме NOUN ['Loc'] 	 obl   |   получить
# одного NUM ['Gen'] 	 nummod   |   окна
# окна NOUN ['Gen'] 	 nmod   |   режиме
# {'predicates': [{'action': ['смогут', 'обратиться'], 'subjects': [[{'item': 'военные', 'modifiers': []}], [{'item': 'семьи', 'modifiers': []}]], 'objects': [[{'item': 'справки', 'modifiers': [['необходимые', set()]]}]]}], 'named entities': []}
# Обратиться в ВСЦ можно из любого муниципалитета Коми. 000
# Обратиться VERB [] 	 csubj   |   можно
# в ADP [] 	 case   |   ВСЦ
# ВСЦ PROPN ['Acc'] 	 obl   |   Обратиться
# можно ADV [] 	 ROOT   |   можно
# из ADP [] 	 case   |   муниципалитета
# любого DET ['Gen'] 	 det   |   муниципалитета
# муниципалитета NOUN ['Gen'] 	 obl   |   можно
# Коми PROPN ['Nom'] 	 appos   |   муниципалитета
# . PUNCT [] 	 punct   |   можно
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['можно'], 'subjects': [], 'objects': []}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': ['ВСЦ', 'Коми']}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
# Вопросы, с которыми можно обратиться, денежное довольствие, социальные гарантии, военная ипотека, выплаты при заключении контракта и другие единовременные выплаты. 000
# Вопросы NOUN ['Nom'] 	 ROOT   |   Вопросы
# , PUNCT [] 	 punct   |   можно
# с ADP [] 	 case   |   которыми
# которыми PRON ['Ins'] 	 obl   |   можно
# можно ADV [] 	 acl:relcl   |   Вопросы
# обратиться VERB [] 	 csubj   |   можно
# , PUNCT [] 	 punct   |   довольствие
# денежное ADJ ['Nom'] 	 amod   |   довольствие
# довольствие NOUN ['Acc'] 	 conj   |   Вопросы
# , PUNCT [] 	 punct   |   гарантии
# социальные ADJ ['Nom'] 	 amod   |   гарантии
# гарантии NOUN ['Nom'] 	 conj   |   Вопросы
# , PUNCT [] 	 punct   |   ипотека
# военная ADJ ['Nom'] 	 amod   |   ипотека
# ипотека NOUN ['Nom'] 	 conj   |   Вопросы
# , PUNCT [] 	 punct   |   выплаты
# выплаты NOUN ['Nom'] 	 conj   |   Вопросы
# при ADP [] 	 case   |   заключении
# заключении NOUN ['Loc'] 	 nmod   |   выплаты
# контракта NOUN ['Gen'] 	 nmod   |   заключении
# и CCONJ [] 	 cc   |   выплаты
# другие ADJ ['Acc'] 	 amod   |   выплаты
# единовременные ADJ ['Nom'] 	 amod   |   выплаты
# выплаты NOUN ['Acc'] 	 conj   |   Вопросы
# . PUNCT [] 	 punct   |   Вопросы
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['Вопросы', 'довольствие', 'гарантии', 'ипотека', 'выплаты', 'выплаты'], 'subjects': [], 'objects': []}, {'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
#  000
#   SPACE [] 	 dep   |
# 000 NUM [] 	 ROOT   |   000
# {'predicates': [{'action': ['000'], 'subjects': [], 'objects': []}], 'named entities': []}
#  Адрес: Сыктывкар, Первомайская, 11 000
#   SPACE [] 	 dep   |   Адрес
# Адрес NOUN ['Nom'] 	 ROOT   |   Адрес
# : PUNCT [] 	 punct   |   Сыктывкар
# Сыктывкар PROPN ['Nom'] 	 parataxis   |   Адрес
# , PUNCT [] 	 punct   |   Первомайская
# Первомайская ADJ ['Nom'] 	 conj   |   Сыктывкар
# , PUNCT [] 	 punct   |   Адрес
# 11 NUM [] 	 nummod   |   000
# 000 NUM [] 	 punct   |   Адрес
# {'predicates': [{'action': ['Адрес'], 'subjects': [], 'objects': []}], 'named entities': ['Первомайская  Сыктывкар']}
#  График работы: будни с 14:00 до 17:00, суббота и воскресенье выходной 000
#   SPACE [] 	 dep   |   График
# График NOUN ['Nom'] 	 ROOT   |   График
# работы NOUN ['Gen'] 	 nmod   |   График
# : PUNCT [] 	 punct   |   будни
# будни NOUN ['Nom'] 	 parataxis   |   График
# с ADP [] 	 case   |   14:00
# 14:00 NUM [] 	 nmod   |   будни
# до ADP [] 	 case   |   17:00
# 17:00 NUM [] 	 obl   |   14:00
# , PUNCT [] 	 punct   |   суббота
# суббота NOUN ['Gen'] 	 conj   |   будни
# и CCONJ [] 	 cc   |   воскресенье
# воскресенье NOUN ['Acc'] 	 conj   |   будни
# выходной ADJ ['Gen'] 	 nmod   |   воскресенье
# 000 NUM [] 	 punct   |   График
# {'predicates': [{'action': ['График'], 'subjects': [], 'objects': []}], 'named entities': []}
#  Телефон: 8(800)707 99 99
#   SPACE [] 	 dep   |   Телефон
# Телефон PROPN ['Nom'] 	 ROOT   |   Телефон
# : PUNCT [] 	 punct   |   8(800)707
# 8(800)707 NUM [] 	 nummod   |   Телефон
# 99 NUM [] 	 flat   |   8(800)707
# 99 NUM [] 	 punct   |   Телефон
# {'predicates': [{'action': ['Телефон'], 'subjects': [], 'objects': []}], 'named entities': ['Телефон']}
